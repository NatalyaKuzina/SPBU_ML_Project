# %% [markdown]
# <a href="https://colab.research.google.com/github/NatalyaKuzina/SPBU_ML_Project/blob/main/Animals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import os
import matplotlib.pyplot as plt
import numpy as np

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)
import os
import zipfile

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68606236/68606236 [==============================] - 0s 0us/step

# %%
zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats

# %%
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')
validation_cats_dir = os.path.join(validation_dir, 'cats')
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
print('Кошек в тестовом наборе данных: ', num_cats_tr)
print('Собак в тестовом наборе данных: ', num_dogs_tr)

print('Кошек в валидационном наборе данных: ', num_cats_val)
print('Собак в валидационном наборе данных: ', num_dogs_val)
print('--')
print('Всего изображений в тренировочном наборе данных: ', total_train)
print('Всего изображений в валидационном наборе данных: ', total_val)
# Out:
# Кошек в тестовом наборе данных:  1000
# Собак в тестовом наборе данных:  1000
# Кошек в валидационном наборе данных:  500
# Собак в валидационном наборе данных:  500
# --
# Всего изображений в тренировочном наборе данных:  2000
# Всего изображений в валидационном наборе данных:  1000

# %%
BATCH_SIZE = 100 # количество тренировочных изображений для обработки перед обновлением параметров модели
IMG_SHAPE = 150 # размерность к которой будет преведено входное изображение

# %%
train_image_generator = ImageDataGenerator(rescale=1./255)
validation_image_generator = ImageDataGenerator(rescale=1./255)

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                          directory=train_dir,
                                                          shuffle=True,
                                                          target_size=(IMG_SHAPE,IMG_SHAPE),
                                                          class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory=validation_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE),
                                                              class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %%
sample_training_images, _ = next(train_data_gen)

# %%
# данная функция отрисует изображения в сетке размером 1х5
def plotImages(images_arr):
  fig, axes = plt.subplots(1, 5, figsize=(20, 20))
  axes = axes.flatten()
  for img, ax in zip(images_arr, axes):
    ax.imshow(img)
  plt.tight_layout()
  plt.show()

# %%
plotImages(sample_training_images[:5]) # отрисовываем изображения 0-4

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(IMG_SHAPE, IMG_SHAPE, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 128)       147584
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 512)               3211776
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
EPOCHS = 100
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE)))
)
# Out:
# <ipython-input-19-d70e0a339f06>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/100
# 20/20 [==============================] - 146s 7s/step - loss: 0.7169 - accuracy: 0.5100 - val_loss: 0.6966 - val_accuracy: 0.5000
# Epoch 2/100
# 20/20 [==============================] - 139s 7s/step - loss: 0.6924 - accuracy: 0.5160 - val_loss: 0.6879 - val_accuracy: 0.6550
# Epoch 3/100
# 20/20 [==============================] - 147s 7s/step - loss: 0.6866 - accuracy: 0.5460 - val_loss: 0.6796 - val_accuracy: 0.5570
# Epoch 4/100
# 20/20 [==============================] - 140s 7s/step - loss: 0.6746 - accuracy: 0.5815 - val_loss: 0.6704 - val_accuracy: 0.5610
# Epoch 5/100
# 20/20 [==============================] - 141s 7s/step - loss: 0.6550 - accuracy: 0.6075 - val_loss: 0.6588 - val_accuracy: 0.6100
# Epoch 6/100
# 20/20 [==============================] - 161s 8s/step - loss: 0.6050 - accuracy: 0.6750 - val_loss: 0.6133 - val_accuracy: 0.6580
# Epoch 7/100
# 20/20 [==============================] - 145s 7s/step - loss: 0.5637 - accuracy: 0.7065 - val_loss: 0.5783 - val_accuracy: 0.7160
# Epoch 8/100
# 20/20 [==============================] - 141s 7s/step - loss: 0.5253 - accuracy: 0.7395 - val_loss: 0.5710 - val_accuracy: 0.7100
# Epoch 9/100
# 20/20 [==============================] - 141s 7s/step - loss: 0.5052 - accuracy: 0.7600 - val_loss: 0.5793 - val_accuracy: 0.7020
# Epoch 10/100
# 20/20 [==============================] - 160s 8s/step - loss: 0.4522 - accuracy: 0.7950 - val_loss: 0.5768 - val_accuracy: 0.7180
# Epoch 11/100
# 20/20 [==============================] - 140s 7s/step - loss: 0.4138 - accuracy: 0.8055 - val_loss: 0.5938 - val_accuracy: 0.7100
# Epoch 12/100
# 20/20 [==============================] - 141s 7s/step - loss: 0.3790 - accuracy: 0.8320 - val_loss: 0.5898 - val_accuracy: 0.7170
# Epoch 13/100
# 20/20 [==============================] - 139s 7s/step - loss: 0.3374 - accuracy: 0.8530 - val_loss: 0.6059 - val_accuracy: 0.7070
# Epoch 14/100
# 20/20 [==============================] - 145s 7s/step - loss: 0.3076 - accuracy: 0.8675 - val_loss: 0.5880 - val_accuracy: 0.7330
# Epoch 15/100
# 20/20 [==============================] - 138s 7s/step - loss: 0.2559 - accuracy: 0.8995 - val_loss: 0.6488 - val_accuracy: 0.7470
# Epoch 16/100
# 20/20 [==============================] - 140s 7s/step - loss: 0.2267 - accuracy: 0.9040 - val_loss: 0.6644 - val_accuracy: 0.7320
# Epoch 17/100
# 20/20 [==============================] - 140s 7s/step - loss: 0.2087 - accuracy: 0.9170 - val_loss: 0.7390 - val_accuracy: 0.7300
# Epoch 18/100
# 20/20 [==============================] - 147s 7s/step - loss: 0.1681 - accuracy: 0.9300 - val_loss: 0.8110 - val_accuracy: 0.7340
# Epoch 19/100
# 20/20 [==============================] - 139s 7s/step - loss: 0.1370 - accuracy: 0.9445 - val_loss: 0.8273 - val_accuracy: 0.7490
# Epoch 20/100
# 20/20 [==============================] - 140s 7s/step - loss: 0.1075 - accuracy: 0.9575 - val_loss: 0.8949 - val_accuracy: 0.7060
# Epoch 21/100
# 20/20 [==============================] - 140s 7s/step - loss: 0.0718 - accuracy: 0.9755 - val_loss: 0.9613 - val_accuracy: 0.7350
# Epoch 22/100
# 20/20 [==============================] - 140s 7s/step - loss: 0.0943 - accuracy: 0.9645 - val_loss: 0.9036 - val_accuracy: 0.7380
# Epoch 23/100
# 20/20 [==============================] - 138s 7s/step - loss: 0.0487 - accuracy: 0.9840 - val_loss: 1.1166 - val_accuracy: 0.7340
# Epoch 24/100
# 20/20 [==============================] - 138s 7s/step - loss: 0.0306 - accuracy: 0.9920 - val_loss: 1.2946 - val_accuracy: 0.7310
# Epoch 25/100
# 20/20 [==============================] - 140s 7s/step - loss: 0.0218 - accuracy: 0.9935 - val_loss: 1.3488 - val_accuracy: 0.7360
# Epoch 26/100
# 20/20 [==============================] - 140s 7s/step - loss: 0.0135 - accuracy: 0.9965 - val_loss: 1.3904 - val_accuracy: 0.7190
# Epoch 27/100
# 20/20 [==============================] - 140s 7s/step - loss: 0.0061 - accuracy: 0.9995 - val_loss: 1.4346 - val_accuracy: 0.7200
# Epoch 28/100
# 20/20 [==============================] - 140s 7s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.5100 - val_accuracy: 0.7300
# Epoch 29/100
# 20/20 [==============================] - 141s 7s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.5776 - val_accuracy: 0.7300
# Epoch 30/100
# 20/20 [==============================] - 140s 7s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.5930 - val_accuracy: 0.7370
# Epoch 31/100
# 20/20 [==============================] - 140s 7s/step - loss: 8.1552e-04 - accuracy: 1.0000 - val_loss: 1.6265 - val_accuracy: 0.7330
# Epoch 32/100
# 20/20 [==============================] - 141s 7s/step - loss: 6.3788e-04 - accuracy: 1.0000 - val_loss: 1.6527 - val_accuracy: 0.7300
# Epoch 33/100
# 20/20 [==============================] - 140s 7s/step - loss: 5.3374e-04 - accuracy: 1.0000 - val_loss: 1.6825 - val_accuracy: 0.7290
# Epoch 34/100
# 20/20 [==============================] - 140s 7s/step - loss: 4.7846e-04 - accuracy: 1.0000 - val_loss: 1.7012 - val_accuracy: 0.7340
# Epoch 35/100
# 20/20 [==============================] - 140s 7s/step - loss: 4.1744e-04 - accuracy: 1.0000 - val_loss: 1.7285 - val_accuracy: 0.7310
# Epoch 36/100
# 20/20 [==============================] - 140s 7s/step - loss: 3.7194e-04 - accuracy: 1.0000 - val_loss: 1.7457 - val_accuracy: 0.7310
# Epoch 37/100
# 20/20 [==============================] - 141s 7s/step - loss: 3.3343e-04 - accuracy: 1.0000 - val_loss: 1.7656 - val_accuracy: 0.7350
# Epoch 38/100
# 20/20 [==============================] - 140s 7s/step - loss: 3.1103e-04 - accuracy: 1.0000 - val_loss: 1.7799 - val_accuracy: 0.7300
# Epoch 39/100
# 20/20 [==============================] - 141s 7s/step - loss: 2.7616e-04 - accuracy: 1.0000 - val_loss: 1.7987 - val_accuracy: 0.7310
# Epoch 40/100
# 20/20 [==============================] - 140s 7s/step - loss: 2.5371e-04 - accuracy: 1.0000 - val_loss: 1.8113 - val_accuracy: 0.7310
# Epoch 41/100
# 20/20 [==============================] - 140s 7s/step - loss: 2.3408e-04 - accuracy: 1.0000 - val_loss: 1.8279 - val_accuracy: 0.7330
# Epoch 42/100
# 20/20 [==============================] - 141s 7s/step - loss: 2.1332e-04 - accuracy: 1.0000 - val_loss: 1.8376 - val_accuracy: 0.7320
# Epoch 43/100
# 20/20 [==============================] - 139s 7s/step - loss: 1.9833e-04 - accuracy: 1.0000 - val_loss: 1.8520 - val_accuracy: 0.7330
# Epoch 44/100
# 20/20 [==============================] - 141s 7s/step - loss: 1.8377e-04 - accuracy: 1.0000 - val_loss: 1.8640 - val_accuracy: 0.7340
# Epoch 45/100
# 20/20 [==============================] - 141s 7s/step - loss: 1.7272e-04 - accuracy: 1.0000 - val_loss: 1.8765 - val_accuracy: 0.7380
# Epoch 46/100
# 20/20 [==============================] - 140s 7s/step - loss: 1.5946e-04 - accuracy: 1.0000 - val_loss: 1.8884 - val_accuracy: 0.7360
# Epoch 47/100
# 20/20 [==============================] - 141s 7s/step - loss: 1.4936e-04 - accuracy: 1.0000 - val_loss: 1.8969 - val_accuracy: 0.7380
# Epoch 48/100
# 20/20 [==============================] - 141s 7s/step - loss: 1.3923e-04 - accuracy: 1.0000 - val_loss: 1.9089 - val_accuracy: 0.7350
# Epoch 49/100
# 20/20 [==============================] - 141s 7s/step - loss: 1.3039e-04 - accuracy: 1.0000 - val_loss: 1.9213 - val_accuracy: 0.7370
# Epoch 50/100
# 20/20 [==============================] - 141s 7s/step - loss: 1.2578e-04 - accuracy: 1.0000 - val_loss: 1.9309 - val_accuracy: 0.7340
# Epoch 51/100
# 20/20 [==============================] - 140s 7s/step - loss: 1.1687e-04 - accuracy: 1.0000 - val_loss: 1.9430 - val_accuracy: 0.7370
# Epoch 52/100
# 20/20 [==============================] - 140s 7s/step - loss: 1.1032e-04 - accuracy: 1.0000 - val_loss: 1.9504 - val_accuracy: 0.7380
# Epoch 53/100
# 20/20 [==============================] - 140s 7s/step - loss: 1.0625e-04 - accuracy: 1.0000 - val_loss: 1.9619 - val_accuracy: 0.7390
# Epoch 54/100
# 20/20 [==============================] - 161s 8s/step - loss: 9.8549e-05 - accuracy: 1.0000 - val_loss: 1.9728 - val_accuracy: 0.7400
# Epoch 55/100
# 20/20 [==============================] - 141s 7s/step - loss: 9.0431e-05 - accuracy: 1.0000 - val_loss: 1.9786 - val_accuracy: 0.7400
# Epoch 56/100
# 20/20 [==============================] - 140s 7s/step - loss: 8.6220e-05 - accuracy: 1.0000 - val_loss: 1.9883 - val_accuracy: 0.7390
# Epoch 57/100
# 20/20 [==============================] - 141s 7s/step - loss: 8.1874e-05 - accuracy: 1.0000 - val_loss: 1.9965 - val_accuracy: 0.7380
# Epoch 58/100
# 20/20 [==============================] - 165s 8s/step - loss: 7.7451e-05 - accuracy: 1.0000 - val_loss: 2.0035 - val_accuracy: 0.7380
# Epoch 59/100
# 20/20 [==============================] - 141s 7s/step - loss: 7.4256e-05 - accuracy: 1.0000 - val_loss: 2.0151 - val_accuracy: 0.7380
# Epoch 60/100
# 20/20 [==============================] - 140s 7s/step - loss: 6.9862e-05 - accuracy: 1.0000 - val_loss: 2.0224 - val_accuracy: 0.7360
# Epoch 61/100
# 20/20 [==============================] - 138s 7s/step - loss: 6.6141e-05 - accuracy: 1.0000 - val_loss: 2.0302 - val_accuracy: 0.7380
# Epoch 62/100
# 20/20 [==============================] - 146s 7s/step - loss: 6.2500e-05 - accuracy: 1.0000 - val_loss: 2.0365 - val_accuracy: 0.7380
# Epoch 63/100
# 20/20 [==============================] - 141s 7s/step - loss: 5.9493e-05 - accuracy: 1.0000 - val_loss: 2.0440 - val_accuracy: 0.7400
# Epoch 64/100
# 20/20 [==============================] - 141s 7s/step - loss: 5.6146e-05 - accuracy: 1.0000 - val_loss: 2.0529 - val_accuracy: 0.7380
# Epoch 65/100
# 20/20 [==============================] - 141s 7s/step - loss: 5.4264e-05 - accuracy: 1.0000 - val_loss: 2.0577 - val_accuracy: 0.7430
# Epoch 66/100
# 20/20 [==============================] - 141s 7s/step - loss: 5.1089e-05 - accuracy: 1.0000 - val_loss: 2.0669 - val_accuracy: 0.7400
# Epoch 67/100
# 20/20 [==============================] - 141s 7s/step - loss: 4.8797e-05 - accuracy: 1.0000 - val_loss: 2.0711 - val_accuracy: 0.7380
# Epoch 68/100
# 20/20 [==============================] - 141s 7s/step - loss: 4.5798e-05 - accuracy: 1.0000 - val_loss: 2.0785 - val_accuracy: 0.7380
# Epoch 69/100
# 20/20 [==============================] - 141s 7s/step - loss: 4.4342e-05 - accuracy: 1.0000 - val_loss: 2.0844 - val_accuracy: 0.7410
# Epoch 70/100
# 20/20 [==============================] - 141s 7s/step - loss: 4.2272e-05 - accuracy: 1.0000 - val_loss: 2.0910 - val_accuracy: 0.7390
# Epoch 71/100
# 20/20 [==============================] - 141s 7s/step - loss: 3.9567e-05 - accuracy: 1.0000 - val_loss: 2.0983 - val_accuracy: 0.7380
# Epoch 72/100
# 20/20 [==============================] - 142s 7s/step - loss: 3.8062e-05 - accuracy: 1.0000 - val_loss: 2.1041 - val_accuracy: 0.7400
# Epoch 73/100
# 20/20 [==============================] - 141s 7s/step - loss: 3.6448e-05 - accuracy: 1.0000 - val_loss: 2.1093 - val_accuracy: 0.7390
# Epoch 74/100
# 20/20 [==============================] - 142s 7s/step - loss: 3.4659e-05 - accuracy: 1.0000 - val_loss: 2.1176 - val_accuracy: 0.7420
# Epoch 75/100
# 20/20 [==============================] - 141s 7s/step - loss: 3.4486e-05 - accuracy: 1.0000 - val_loss: 2.1229 - val_accuracy: 0.7370
# Epoch 76/100
# 20/20 [==============================] - 140s 7s/step - loss: 3.1847e-05 - accuracy: 1.0000 - val_loss: 2.1300 - val_accuracy: 0.7420
# Epoch 77/100
# 20/20 [==============================] - 141s 7s/step - loss: 3.0537e-05 - accuracy: 1.0000 - val_loss: 2.1363 - val_accuracy: 0.7380
# Epoch 78/100
# 20/20 [==============================] - 141s 7s/step - loss: 2.9419e-05 - accuracy: 1.0000 - val_loss: 2.1422 - val_accuracy: 0.7370
# Epoch 79/100
# 20/20 [==============================] - 141s 7s/step - loss: 2.8143e-05 - accuracy: 1.0000 - val_loss: 2.1481 - val_accuracy: 0.7360
# Epoch 80/100
# 20/20 [==============================] - 142s 7s/step - loss: 2.7040e-05 - accuracy: 1.0000 - val_loss: 2.1537 - val_accuracy: 0.7380
# Epoch 81/100
# 20/20 [==============================] - 141s 7s/step - loss: 2.6001e-05 - accuracy: 1.0000 - val_loss: 2.1612 - val_accuracy: 0.7400
# Epoch 82/100
# 20/20 [==============================] - 141s 7s/step - loss: 2.5119e-05 - accuracy: 1.0000 - val_loss: 2.1637 - val_accuracy: 0.7390
# Epoch 83/100
# 20/20 [==============================] - 139s 7s/step - loss: 2.4014e-05 - accuracy: 1.0000 - val_loss: 2.1694 - val_accuracy: 0.7390
# Epoch 84/100
# 20/20 [==============================] - 140s 7s/step - loss: 2.3297e-05 - accuracy: 1.0000 - val_loss: 2.1754 - val_accuracy: 0.7390
# Epoch 85/100
# 20/20 [==============================] - 141s 7s/step - loss: 2.2300e-05 - accuracy: 1.0000 - val_loss: 2.1822 - val_accuracy: 0.7380
# Epoch 86/100
# 20/20 [==============================] - 142s 7s/step - loss: 2.2641e-05 - accuracy: 1.0000 - val_loss: 2.1879 - val_accuracy: 0.7370
# Epoch 87/100
# 20/20 [==============================] - 143s 7s/step - loss: 2.1331e-05 - accuracy: 1.0000 - val_loss: 2.1916 - val_accuracy: 0.7370
# Epoch 88/100
# 20/20 [==============================] - 141s 7s/step - loss: 2.0487e-05 - accuracy: 1.0000 - val_loss: 2.1974 - val_accuracy: 0.7380
# Epoch 89/100
# 20/20 [==============================] - 141s 7s/step - loss: 1.9782e-05 - accuracy: 1.0000 - val_loss: 2.2035 - val_accuracy: 0.7410
# Epoch 90/100
# 20/20 [==============================] - 162s 8s/step - loss: 1.8813e-05 - accuracy: 1.0000 - val_loss: 2.2067 - val_accuracy: 0.7400
# Epoch 91/100
# 20/20 [==============================] - 141s 7s/step - loss: 1.8299e-05 - accuracy: 1.0000 - val_loss: 2.2131 - val_accuracy: 0.7360
# Epoch 92/100
# 20/20 [==============================] - 141s 7s/step - loss: 1.7633e-05 - accuracy: 1.0000 - val_loss: 2.2175 - val_accuracy: 0.7390
# Epoch 93/100
# 20/20 [==============================] - 141s 7s/step - loss: 1.7180e-05 - accuracy: 1.0000 - val_loss: 2.2226 - val_accuracy: 0.7370
# Epoch 94/100
# 20/20 [==============================] - 162s 8s/step - loss: 1.6650e-05 - accuracy: 1.0000 - val_loss: 2.2268 - val_accuracy: 0.7390
# Epoch 95/100
# 20/20 [==============================] - 141s 7s/step - loss: 1.6046e-05 - accuracy: 1.0000 - val_loss: 2.2318 - val_accuracy: 0.7350
# Epoch 96/100
# 20/20 [==============================] - 142s 7s/step - loss: 1.5591e-05 - accuracy: 1.0000 - val_loss: 2.2371 - val_accuracy: 0.7380
# Epoch 97/100
# 20/20 [==============================] - 141s 7s/step - loss: 1.5090e-05 - accuracy: 1.0000 - val_loss: 2.2420 - val_accuracy: 0.7380
# Epoch 98/100
# 20/20 [==============================] - 141s 7s/step - loss: 1.4705e-05 - accuracy: 1.0000 - val_loss: 2.2459 - val_accuracy: 0.7350
# Epoch 99/100
# 20/20 [==============================] - 142s 7s/step - loss: 1.4279e-05 - accuracy: 1.0000 - val_loss: 2.2522 - val_accuracy: 0.7350
# Epoch 100/100
# 20/20 [==============================] - 143s 7s/step - loss: 1.3928e-05 - accuracy: 1.0000 - val_loss: 2.2576 - val_accuracy: 0.7370

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8,8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Точность на обучении')
plt.plot(epochs_range, val_acc, label='Точность на валидации')
plt.legend(loc='lower right')
plt.title('Точность')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Потери на обучении')
plt.plot(epochs_range, val_loss, label='Потери на валидации')
plt.legend(loc='upper right')
plt.title('Потери')
plt.savefig('./foo.png')
plt.show()
